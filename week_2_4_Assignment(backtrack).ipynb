# %% [markdown]
# <a href="https://colab.research.google.com/github/Manusree1324/competitiveProgrammming/blob/main/week_2_4_Assignment(backtrack).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def subset_sum(arr, n, target):
    # Base cases
    if target == 0:
        return True
    if n == 0 or target < 0:
        return False

    # Include or exclude current element
    return (subset_sum(arr, n - 1, target - arr[n - 1]) or
            subset_sum(arr, n - 1, target))


# Input
n = int(input())
arr = list(map(int, input().split()))
target = int(input())

# Output
print(subset_sum(arr, n, target))
# Out:
# 5
# 3 34 4 12 5
# 9
# True
